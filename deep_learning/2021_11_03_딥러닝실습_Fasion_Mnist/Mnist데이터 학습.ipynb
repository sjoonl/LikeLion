# %%
import numpy
import matplotlib

# %%
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
  import matplotlib.pyplot as plt

# %%
figures, axes = plt.subplots(nrows = 3, ncols = 5)
figures.set_size_inches(18,12)

plt.gray()
print("label = {}".format(y_train[0:15]))

col = 0
for row in range(0,3):
  col = row*5
  axes[row][0].imshow(X_train[col])
  axes[row][1].imshow(X_train[col+1])
  axes[row][2].imshow(X_train[col+2])
  axes[row][3].imshow(X_train[col+3])
  axes[row][4].imshow(X_train[col+4])
# Out:
# label = [5 0 4 1 9 2 1 3 1 4 3 5 3 6 1]

# %%
fig, axes = plt.subplots(3, 5, figsize=(18,12),
                        subplot_kw= {'xticks':(), 'yticks':() })

for image, ax in zip( X_train, axes.ravel() ):
    ax.imshow(image) # 이미지 표시

# %%
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)

y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
X_train = X_train.reshape(X_train.shape[0], 784).astype('float64')/255

# %%
import numpy as np

# %%
np.min(X_train), np.max(X_train)
# Out:
# (0.0, 1.0)

# %%
X_test = X_test.reshape(X_test.shape[0], 784).astype('float64')/255

# %%
np.min(X_test), np.max(X_test)
# Out:
# (0.0, 1.0)

# %%
y_train = np_utils.to_categorical(y_train, 10)
y_test = np_utils.to_categorical(y_test, 10)

# %%
model = Sequential()
model.add(Dense(512,input_dim=784, activation = 'relu'))
model.add(Dense(128,activation = 'relu'))
model.add(Dense(10, activation='softmax'))



#model.add(Dense(units = 64, input_dim = 784, activation = 'relu'))
#model.add(Dense(units = 10,))

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model = Sequential()
model.add(Dense(units = 64, input_dim = 784, activation = 'relu'))
model.add(Dense(units = 10,))

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'sgd', metrics = ['accuracy'])

# %%
hist = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.4654 - accuracy: 0.2922 - val_loss: 8.9183 - val_accuracy: 0.2948
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 8.7688 - accuracy: 0.2954 - val_loss: 8.8715 - val_accuracy: 0.2935
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 8.7594 - accuracy: 0.2959 - val_loss: 8.9053 - val_accuracy: 0.2944
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.7878 - accuracy: 0.2956 - val_loss: 8.8795 - val_accuracy: 0.2936
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 8.7484 - accuracy: 0.2955 - val_loss: 8.8908 - val_accuracy: 0.2936
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.7803 - accuracy: 0.2954 - val_loss: 8.9198 - val_accuracy: 0.2939
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 8.8123 - accuracy: 0.2954 - val_loss: 8.9392 - val_accuracy: 0.2940
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 8.8195 - accuracy: 0.2953 - val_loss: 8.9392 - val_accuracy: 0.2940
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 8.8195 - accuracy: 0.2953 - val_loss: 8.9392 - val_accuracy: 0.2940
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 8.8195 - accuracy: 0.2953 - val_loss: 8.9392 - val_accuracy: 0.2940

# %%
print("test Accuracy: %.4f" %(model.evaluate(X_test, y_test)[1]))
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 8.9392 - accuracy: 0.2940
# test Accuracy: 0.2940
