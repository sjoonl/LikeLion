# %% [markdown]
# ## Cluster analysis(군집화 분석)
#
# * Cluster analysis(군집화 분석)이란 주어진 데이터들의 특성을 고려해 데이터 집단(Cluster)을 정의하고 데이터 집단의 대표할 수 있는 대표점을 찾는 것으로 데이터 마이닝의 한 방법이다.
#
# * Cluster란 비슷한 특성을 가진 데이터들의 집단. 반대로 데이터의 특성이 다르면 다른 클러스터에 속해야 한다.
#
# * 효율성 : Cluster 분석을 통해 수백만의 데이터를 직접 확인하지 않고 각각 Cluster의 대표값만 확인해 전체 데이터의 특성을 파악할 수 있다.
#
# 출처 : [클러스터 분석 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%ED%81%B4%EB%9F%AC%EC%8A%A4%ED%84%B0_%EB%B6%84%EC%84%9D)
#
#
# ## scikit-learn의 Clustering 알고리즘 비교
# <img src="https://scikit-learn.org/stable/_images/sphx_glr_plot_cluster_comparison_001.png">
#
# 출처 : [scikit-learn 2.3.1. Overview of clustering method](https://scikit-learn.org/stable/modules/clustering.html#clustering)
#
#
# ## K-Means
#
# * 주어진 데이터를 k개의 클러스터로 묶는 알고리즘으로, 각 클러스터와 거리 차이의 분산을 최소화하는 방식으로 동작한다.
#
# * 이 알고리즘은 자율 학습의 일종으로, 레이블이 달려 있지 않은 입력 데이터에 레이블을 달아주는 역할을 수행한다.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Kmeans_animation_withoutWatermark.gif/220px-Kmeans_animation_withoutWatermark.gif">
#
# 출처 : [K-평균_알고리즘 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/K-%ED%8F%89%EA%B7%A0_%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 라이브러리 로드

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 파일 불러오기

# %%
# rfm.csv 파일을 읽어오고, index는 "CustomerID"로 설정해 줍니다.

rfm = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2021_10_26_박조은 강사님 실습(retail 분석)/rfm.csv")
rfm = rfm.set_index("CustomerID")
rfm
# Out:
#             Recency  Frequency  MonetaryValue  ...  RFM_segment  RFM_score  RFM_class
# CustomerID                                     ...
# 12346.0         326          1       77183.60  ...          115          7     silver
# 12347.0           2        182        4310.00  ...          555         15   platinum
# 12348.0          75         31        1797.24  ...          234          9       gold
# 12349.0          19         73        1757.55  ...          444         12   platinum
# 12350.0         310         17         334.40  ...          122          5     silver
# ...             ...        ...            ...  ...          ...        ...        ...
# 18280.0         278         10         180.60  ...          111          3     silver
# 18281.0         181          7          80.82  ...          111          3     silver
# 18282.0           8         12         178.05  ...          511          7     silver
# 18283.0           4        721        2045.53  ...          554         14   platinum
# 18287.0          43         70        1837.28  ...          344         11       gold
#
# [4338 rows x 9 columns]

# %% [markdown]
# ## rfm_cluster 변수 생성

# %%
# iloc를 사용하여 Recency, Frequency, MonetaryValue 컬럼 데이터를 rfm_cluster 변수에 담습니다.

rfm_cluster = rfm.iloc[:, :3]
rfm_cluster
# Out:
#             Recency  Frequency  MonetaryValue
# CustomerID
# 12346.0         326          1       77183.60
# 12347.0           2        182        4310.00
# 12348.0          75         31        1797.24
# 12349.0          19         73        1757.55
# 12350.0         310         17         334.40
# ...             ...        ...            ...
# 18280.0         278         10         180.60
# 18281.0         181          7          80.82
# 18282.0           8         12         178.05
# 18283.0           4        721        2045.53
# 18287.0          43         70        1837.28
#
# [4338 rows x 3 columns]

# %%
_ = rfm_cluster.hist(figsize = (12, 6), bins = 100)

# %% [markdown]
# ## 정규화
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/17/Binary_logarithm_plot_with_ticks.svg/1200px-Binary_logarithm_plot_with_ticks.svg.png" width="300">

# %%
# np.log1p 메서드를 사용하여 값들을 정규화 시켜주고, rfm_cluster_log 변수에 담습니다.
# 정규화시 np.log보다 np.log1p을 사용하는 이유는 x값이 1보다 작을 때, y값이 음의 무한대로 가는 것을 방지하기 위함입니다.
# 정규화를 함으로써 각 속성별로 다양한 수의 범위를 줄여줄 수 있습니다.

rfm_cluster_log = np.log1p(rfm_cluster)
rfm_cluster_log
# Out:
#              Recency  Frequency  MonetaryValue
# CustomerID
# 12346.0     5.789960   0.693147      11.253955
# 12347.0     1.098612   5.209486       8.368925
# 12348.0     4.330733   3.465736       7.494564
# 12349.0     2.995732   4.304065       7.472245
# 12350.0     5.739793   2.890372       5.815324
# ...              ...        ...            ...
# 18280.0     5.631212   2.397895       5.201806
# 18281.0     5.204007   2.079442       4.404522
# 18282.0     2.197225   2.564949       5.187665
# 18283.0     1.609438   6.582025       7.623901
# 18287.0     3.784190   4.262680       7.516586
#
# [4338 rows x 3 columns]

# %%
_ = rfm_cluster_log.hist(figsize = (12, 6), bins =100)

# %% [markdown]
# ## 스케일 조정하기

# %%
# StandardScaler 메서드를 사용하여 속성 값의 범위가 크게 차이 나지 않도록 평균 0, 분산 1로 조정해 줍니다.

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(rfm_cluster_log)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# fit_transform 메서드를 사용하여 rfm_cluster_log를 rfm_norm 변수에 담습니다.

rfm_norm = scaler.fit_transform(rfm_cluster_log)
rfm_norm
# Out:
# array([[ 1.46190736, -2.43788926,  3.71030846],
#        [-2.0405272 ,  1.18891259,  1.41710205],
#        [ 0.37248773, -0.211389  ,  0.72210361],
#        ...,
#        [-1.22033272, -0.93475683, -1.11156693],
#        [-1.65915848,  2.2911166 ,  0.82490915],
#        [-0.03554715,  0.42858907,  0.73960806]])

# %% [markdown]
# ### K-Means 모델 학습

# %%
inertia = []
# rfm_norm 값을 학습하고
# 리스트에 inertia_ 값을 넣어 elbow 값을 봅니다.
from sklearn.cluster import KMeans

for i in  range(1, 20):
  kmeans = KMeans(n_clusters = i, random_state = 42)
  kmeans.fit(rfm_norm)
  inertia.append(kmeans.inertia_)

# %% [markdown]
# ## 시각화

# %%
# The Elbow Method 그래프에서 급격히 떨어지는 구간을 확인하여, 적절한 K값을 확인해 봅니다.

plt.figure(figsize=(15,4))
plt.plot(range(1, 20), inertia)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-Cluster Sum of Square')
plt.xticks(range(1, 20))
plt.grid(True)
plt.show()

# %%
# n_clusters의 수를 늘려 봅니다.

kmeans = KMeans(n_clusters = 5, random_state = 42)
kmeans.fit(rfm_norm)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
# cluster_centers_를 통해서 좌표값을 출력해 봅니다.
kmeans.cluster_centers_
# Out:
# array([[ 0.0117978 ,  0.65875557,  0.62351118],
#        [ 0.82514926, -0.2939282 , -0.33530622],
#        [ 0.83502231, -1.37611036, -1.22951828],
#        [-0.82759726, -0.27233146, -0.35453291],
#        [-1.35717057,  1.33107531,  1.38461718]])

# %%
# labels_를 통해서 어떤 클러스터에 속하는지 확인합니다.
kmeans.labels_
# Out:
# array([0, 4, 0, ..., 3, 4, 0], dtype=int32)

# %%
# rfm['Cluster']에 kmeans.labels_ 값을 담아줍니다.

rfm['Cluster'] = kmeans.labels_

# %%
# Cluster와 RFM_score의 상관관계를 살펴보기 위해 scatterplot으로 산점도를 출력해 봅니다.(RFM_class를 통해 데이터를 구분할 수 있습니다.)
sns.scatterplot(data = rfm, x = "Cluster", y = "RFM_score", hue = "RFM_class")

# %%
# stripplot은 scatterplot과 유사하나 데이터가 겹치면 양 옆으로 흩어진 형태를 보입니다.
sns.stripplot(data = rfm, x = "Cluster", y = "RFM_score", hue = "RFM_class")

# %%
# MonetaryValue와 RFM_score의 상관관계를 살펴보기 위해 scatterplot으로 산점도를 출력해 봅니다.
# RFM_class를 통해 데이터를 구분할 수 있습니다.
sns.stripplot(data = rfm, x = "MonetaryValue", y = "RFM_score", hue = "RFM_class")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-bc104e22c6fb> in <module>()
#       1 # MonetaryValue와 RFM_score의 상관관계를 살펴보기 위해 scatterplot으로 산점도를 출력해 봅니다.
#       2 # RFM_class를 통해 데이터를 구분할 수 있습니다.
# ----> 3 sns.stripplot(data = rfm, x = "MonetaryValue", y = "RFM_score", hue = "RFM_class")
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2820                        linewidth=linewidth))
#    2821
# -> 2822     plotter.plot(ax, kwargs)
#    2823     return ax
#    2824
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in plot(self, ax, kws)
#    1158     def plot(self, ax, kws):
#    1159         """Make the plot."""
# -> 1160         self.draw_stripplot(ax, kws)
#    1161         self.add_legend_data(ax)
#    1162         self.annotate_axes(ax)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in draw_stripplot(self, ax, kws)
#    1127
#    1128                 strip_data = group_data[hue_mask]
# -> 1129                 point_colors = np.asarray(self.point_colors[i][hue_mask])
#    1130
#    1131                 # Plot the points in centered positions
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in point_colors(self)
#    1076                     # hue_color = self.colors[j]
#    1077                     if group_data.size:
# -> 1078                         group_colors[self.plot_hues[i] == level] = j
#    1079
#    1080             point_colors.append(group_colors)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     370         res_values = comparison_op(lvalues, rvalues, op)
#     371
# --> 372         return self._construct_result(res_values, name=res_name)
#     373
#     374     wrapper.__name__ = op_name
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _construct_result(self, result, name)
#    2768         # We do not pass dtype to ensure that the Series constructor
#    2769         #  does inference in the case where `result` has object-dtype.
# -> 2770         out = self._constructor(result, index=self.index)
#    2771         out = out.__finalize__(self)
#    2772
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     331         generic.NDFrame.__init__(self, data)
#     332         self.name = name
# --> 333         self._set_axis(0, index, fastpath=True)
#     334
#     335     def _init_dict(self, data, index=None, dtype=None):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _set_axis(self, axis, labels, fastpath)
#     419                     pass
#     420
# --> 421         object.__setattr__(self, "_index", labels)
#     422         if not fastpath:
#     423             # The ensure_index call above ensures we have an Index object
#
# KeyboardInterrupt:

# %%
# Frequency와 RFM_score의 살펴보기 위해 산점도를 출력해 봅니다.
# RFM_class를 통해 데이터를 구분할 수 있습니다.
sns.scatterplot(data = rfm, x = "Frequency", y = "RFM_score", hue = "Cluster")

# %%
# pairplot을 통해 rfm의 데이터 중 무작위로 1000개의 데이터만을 추출해 pairplot을 시각화 합니다.
# RFM_class를 통해 데이터를 구분할 수 있습니다.

sns.pairplot(data = rfm.sample(1000), hue = "Cluster")
